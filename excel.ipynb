# %%
import numpy as np
import pandas as pd

# %%
legajo_tarjeta = pd.read_excel('legajo_reloj.xls', )
legajo_tarjeta
# Out:
#       Nro Identificador  Nro Tarjeta Apellido y Nombre           Privilegio  \
# 0                     9           11             ADMIN  Super administrador
# 1                    10                          ADMIN  Super administrador
# 2                    16                          ADMIN  Super administrador
# 3                    17                          ADMIN  Super administrador
# 4                    18                          ADMIN  Super administrador
# ...                 ...          ...               ...                  ...
# 1519               9139       111335          CEI FACU             Empleado
# 1520               9140       111536          lopez wa             Empleado
# 1521               9142       123563          FORTUNOF             Empleado
# 1522              60202  0000122100           VILLAMOR             Empleado
# 1523              60206      5512167          SOLIS NO             Empleado
#
#        Clave  Cant. Huellas Habilitado
# ...

# %%
usuario_reloj = pd.read_excel('usuario_datos.xlsx', )
usuario_reloj
# Out:
#      legajo   apellido            nombre tipo_doc   nro_doc     fecnac  \
# 0       577      COLON     NORMA BEATRIZ      DNI  17585757 1966-07-08
# 1       617   MARTINEZ  GRISELDA MARIELA      DNI  22917962 1973-03-28
# 2       625   TAVOLONI          GABRIELA      DNI  22800094 1972-05-31
# 3       649   GONZALEZ       SILVIA NOEM      DNI  13974459 1960-02-03
# 4       691     ROBURU     CLAUDIO OSCAR      DNI  20359535 1968-06-20
# ..      ...        ...               ...      ...       ...        ...
# 246    9134       DIAZ     MARIA EUGENIA      DNI  37033426 1992-10-21
# 247    9135       DANS     NATACHA BELEN      DNI  38769819 1995-04-18
# 248    9136      GOMEZ    MARIA VICTORIA      DNI  37016552 1992-06-23
# 249    9137    SERVERA   EVELYN AGUSTINA      DNI  38083073 1994-01-21
# 250    9142  FORTUNOFF      FACUNDO IVAN      DNI  42294451 2000-01-19
#
#           domicilio     nro  localidad antiguedad  ...  descripcion  nro.1  \
# ...

# %%
inner = pd.merge(left=legajo_tarjeta, right=usuario_reloj, left_on='Nro Identificador', right_on='legajo')
inner
# Out:
#      Nro Identificador  Nro Tarjeta Apellido y Nombre Privilegio Clave  \
# 0                  577  0005138594           COLON NO   Empleado  577
# 1                  617  0000098570           MARTINEZ   Empleado  617
# 2                  625  0000120850           TAVOLONI   Empleado  625
# 3                  649  0007220073           GONZALEZ   Empleado  649
# 4                  691  0000111134           RODURU C   Empleado  691
# ..                 ...          ...               ...        ...   ...
# 246               9134        85212          DIAZ EUG   Empleado
# 247               9135        89982          DANS NAT   Empleado
# 248               9136        91965          GOMEZ MA   Empleado
# 249               9137       122921           SERVERA   Empleado
# 250               9142       123563          FORTUNOF   Empleado
#
#      Cant. Huellas Habilitado  legajo   apellido            nombre  ...  \
# 0                0         Si     577      COLON     NORMA BEATRIZ  ...
# ...

# %% [markdown]
# ## Extract useful data

# %%
merged = inner[['Nro Identificador', 'Nro Tarjeta', 'apellido',
                    'nombre', 'fecnac', 'antiguedad', 'domicilio', 'nro']]
merged['nro'][merged['nro'].isnull()] = 0
merged['nro'][merged['nro'] == 0] 
merged['nro'] = merged['nro'].astype(np.intc)
# Out:
# /tmp/ipykernel_1656/1440233949.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged['nro'][merged['nro'].isnull()] = 0
# /tmp/ipykernel_1656/1440233949.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged['nro'][merged['nro'].isnull()] = 0
# /tmp/ipykernel_1656/1440233949.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %% [markdown]
# ## Concatenate last name and name, then delete the columns

# %%
merged['Nombre'] = merged.apply(
    lambda x: x['apellido'] + ' ' + x['nombre'], axis=1)
del merged['nombre']
del merged['apellido']
# Out:
# /tmp/ipykernel_1656/255037504.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged['Nombre'] = merged.apply(

# %% [markdown]
# ## Concatenate address and number, the delete the columns

# %%
merged['Domicilio'] = merged.apply(
    lambda x: x['domicilio'] + ' ' + str(x['nro']), axis=1)
del merged['domicilio']
del merged['nro']
# Out:
# /tmp/ipykernel_1656/2291958983.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged['Domicilio'] = merged.apply(

# %% [markdown]
# ## Add user number

# %%
length = merged.shape[0]
merged['Usuario Nro.'] = np.arange(1, length + 1)
# Out:
# /tmp/ipykernel_1656/3119433264.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged['Usuario Nro.'] = np.arange(1, length + 1)

# %% [markdown]
# ## Add needed columns

# %%
merged['Género'] = np.nan
merged['Departamento'] = 'Hospital'
merged['Posición'] = np.nan
merged['Teléfono'] = np.nan
merged['Dispositivos'] = np.nan
# Out:
# /tmp/ipykernel_1656/734585417.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged['Género'] = np.nan
# /tmp/ipykernel_1656/734585417.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged['Departamento'] = 'Hospital'
# /tmp/ipykernel_1656/734585417.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# ## Correct columns types

# %%
merged['fecnac'] = merged['fecnac'].astype(str)
for el in merged['fecnac']:
    el = el[6:16]
merged['antiguedad'] = merged['antiguedad'].astype(str)
for el in merged['antiguedad']:
    el = el[6:16]
# Out:
# /tmp/ipykernel_1656/3914802821.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged['fecnac'] = merged['fecnac'].astype(str)
# /tmp/ipykernel_1656/3914802821.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged['antiguedad'] = merged['antiguedad'].astype(str)

# %% [markdown]
# ## Rename columns

# %%
merged = merged.rename(columns={"Nro Identificador": "ID en dispositivo", "Nro Tarjeta": "Tarjeta Nro.", "fecnac": "Cumpleaños", "antiguedad": "Fecha de inicio laboral", "B": "c"})

# %% [markdown]
# ## Generate final output

# %%
final_dataframe = merged[['Usuario Nro.', 'ID en dispositivo', 'Tarjeta Nro.', 'Nombre',
                              'Departamento', 'Género', 'Posición', 'Cumpleaños', 'Fecha de inicio laboral', 'Teléfono', 'Domicilio', 'Dispositivos']]
final_dataframe.fillna('', inplace=True)
final_dataframe.loc[final_dataframe['Cumpleaños'] == 'NaT', 'Cumpleaños'] = '1990-01-01'
final_dataframe.to_excel('Reloj Hospital.xlsx', index=False)
